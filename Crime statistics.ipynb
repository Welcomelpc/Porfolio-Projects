# %% [markdown]
# <u>CLEANING SA CRIME STATISTICS DATA FROM 2005-2016 USING PANDAS</u>
# =

# %%
import pandas as pd

# %% [markdown]
# Reading the dataset
# ===

# %%
df = pd.read_csv(r"C:\Users\LungeloNkambule\Documents\Projects\Python\crime_statistics_south africa\SouthAfricaCrimeStats.csv")
df
# Out:
#            Province            Station                           Category  \
# 0      Western Cape  Cape Town Central  All theft not mentioned elsewhere
# 1           Gauteng        Jhb Central  All theft not mentioned elsewhere
# 2      Western Cape    Mitchells Plain  All theft not mentioned elsewhere
# 3        Free State          Park Road  All theft not mentioned elsewhere
# 4           Gauteng   Pretoria Central  All theft not mentioned elsewhere
# ...             ...                ...                                ...
# 30856  Western Cape             Belhar  All theft not mentioned elsewhere
# 30857       Gauteng         Moffatview  All theft not mentioned elsewhere
# 30858  Western Cape             Belhar                 Drug-related crime
# 30859  Western Cape          Lentegeur  All theft not mentioned elsewhere
# 30860  Western Cape          Lentegeur                 Drug-related crime
#
#        2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# ...

# %% [markdown]
# Dropping any available dupplicates
# ===

# %%
df.drop_duplicates()
# Out:
#            Province            Station                           Category  \
# 0      Western Cape  Cape Town Central  All theft not mentioned elsewhere
# 1           Gauteng        Jhb Central  All theft not mentioned elsewhere
# 2      Western Cape    Mitchells Plain  All theft not mentioned elsewhere
# 3        Free State          Park Road  All theft not mentioned elsewhere
# 4           Gauteng   Pretoria Central  All theft not mentioned elsewhere
# ...             ...                ...                                ...
# 30856  Western Cape             Belhar  All theft not mentioned elsewhere
# 30857       Gauteng         Moffatview  All theft not mentioned elsewhere
# 30858  Western Cape             Belhar                 Drug-related crime
# 30859  Western Cape          Lentegeur  All theft not mentioned elsewhere
# 30860  Western Cape          Lentegeur                 Drug-related crime
#
#        2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# ...

# %% [markdown]
# From the previous query , we can notice that our dataset did not have any available duplicates , hence that's why the same number of rows are still returned.

# %% [markdown]
# Dropping the columns that we found not to be useful
# ==

# %%
df = df.drop(columns = "Category")
df
# Out:
#            Province            Station  2005-2006  2006-2007  2007-2008  \
# 0      Western Cape  Cape Town Central       6692       6341       5966
# 1           Gauteng        Jhb Central       6093       4602       3761
# 2      Western Cape    Mitchells Plain       5341       6093       6316
# 3        Free State          Park Road       5108       4282       3834
# 4           Gauteng   Pretoria Central       5099       4536       3309
# ...             ...                ...        ...        ...        ...
# 30856  Western Cape             Belhar          0          0        250
# 30857       Gauteng         Moffatview          0          0          0
# 30858  Western Cape             Belhar          0          0         54
# 30859  Western Cape          Lentegeur          0          0          0
# 30860  Western Cape          Lentegeur          0          0          0
#
#        2008-2009  2009-2010  2010-2011  2011-2012  2012-2013  2013-2014  \
# ...
